# %% [markdown]
# <div style="text-align: center;">
#   <img src="https://github.com/Hack-io-Data/Imagenes/blob/main/01-LogosHackio/logo_amarillo@4x.png?raw=true" alt="esquema" />
# </div>

# %% [markdown]
# # Laboratorio ETL: Análisis del Sistema Energético en España
#
# ## Objetivo
#
# Durante todos los laboratorios de esta semana realizarás un proceso completo de ETL para analizar la relación entre la demanda, el consumo y la generación eléctrica en diferentes provincias de España a lo largo de un año. Además, complementarán este análisis con datos demográficos y económicos extraídos del Instituto Nacional de Estadística (INE). El **objetivo principal** del análisis es **examinar cómo la demanda, el consumo y la generación eléctrica en diferentes provincias de España a lo largo de los años están influenciados por factores demográficos y económicos, como la población y el PIB provincial**. El análisis busca identificar patrones y correlaciones entre estas variables para comprender mejor las dinámicas energéticas regionales y su relación con el desarrollo socioeconómico en España.
#
# Antes de realizar el análisis, vamos a definir las hipótesis con las que vamos a trabajar, las cuales definirán todo tu análisis y planteamiento de los laboratorios:
#
# - **Hipótesis 1: La demanda eléctrica está correlacionada con la población de la provincia.** Provincias con mayor población tienden a tener una mayor demanda eléctrica.
#
# - **Hipótesis 2: El crecimiento económico (medido por el PIB) está correlacionado con el consumo eléctrico.** Las provincias con un PIB más alto o en crecimiento experimentan un mayor consumo de energía.
#
# - **Hipótesis 3: La proporción de generación renovable está relacionada con factores económicos o geográficos.** Provincias con un mayor desarrollo económico o con condiciones geográficas favorables (como más horas de sol o viento) tienden a generar más energía renovable.
#
#
# ## Tareas Laboratorio Transformación
#
# En este laboratorio, tu objetivo será limpiar y preparar los datos extraídos previamente de diferentes fuentes para su posterior análisis. Trabajarás con datos provenientes de la API de Red Eléctrica Española (REE) y del Instituto Nacional de Estadística (INE). Estos datos incluyen información sobre demanda y generación eléctrica a nivel provincial, así como datos demográficos y económicos.

# %%
# Para gestionar ficheros
# -----------------------------------------------------------------------
import os
import glob
from geopy.geocoders import Nominatim
# Para trabajar con access
# -----------------------------------------------------------------------
import subprocess
import json
# Para trabajar con regex
# -----------------------------------------------------------------------
import re
# Para trabajar con ficheros
# -----------------------------------------------------------------------
import os
# Para trabajar con los DataFrames
# -----------------------------------------------------------------------
import pandas as pd
# Para poner barras progreso
# -----------------------------------------------------------------------
from tqdm import tqdm
# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# Ignorar warings
# -----------------------------------------------------------------------
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# - Cargar los Datos Extraídos:
#
#   - **Demanda Eléctrica:** Carga los datos de demanda eléctrica extraídos de la API de REE.

# %%
ruta_og = "datos/DatosDescargados/RedElectrica/EvolucionDemanda/"
years = os.listdir(ruta_og)
df_demanda = pd.DataFrame()
for year in years:
    ruta_years = os.path.join(ruta_og,year) # Entrar a cada carpeta
    archivos = os.listdir(ruta_years)
    comunidads = []
    yeardatosl = []
    for archivo in archivos:
        comunidad = archivo.split("_")[1]
        comunidads.append(comunidad)
        yeardatos = archivo.split("_")[2].strip(".json")
        yeardatosl.append(yeardatos)
        communi = []
        fechas = []
        porcentaje = []
        demanda = []
        with open(f"{ruta_years}/{archivo}") as f:
            data = json.load(f)

        for valor in data["included"][0]["attributes"]["values"]:
            communi.append(comunidad)
            demanda.append(valor["value"])
            porcentaje.append(valor["percentage"])
            fechas.append(valor["datetime"])
    
        df_temp = pd.DataFrame({
            "comunidad_autónoma" : communi,
            "demanda (MW)" : demanda,
            "porcentaje (%)" : porcentaje,
            "fecha" : fechas
        })
        df_demanda = pd.concat([df_demanda,df_temp])
            
df_demanda.sample(5)
# Out:
#             comunidad_autónoma  demanda (MW)  porcentaje (%)  \
# 4       Principado de Asturias    776093.729               1
# 5                     Canarias    714689.013               1
# 6             Región de Murcia    934973.704               1
# 10  Comunidad Foral de Navarra    437375.677               1
# 3             Región de Murcia    706783.625               1
#
#                             fecha
# 4   2021-05-01T00:00:00.000+02:00
# 5   2019-06-01T00:00:00.000+02:00
# 6   2019-07-01T00:00:00.000+02:00
# 10  2021-11-01T00:00:00.000+01:00
# 3   2021-04-01T00:00:00.000+02:00

# %%
df_demanda.shape
# Out:
# (684, 4)

# %% [markdown]
#   - **Generación Eléctrica:** Carga los datos de generación eléctrica diferenciados por tipo de energía (eólica, solar, hidroeléctrica, etc.) a nivel provincial.

# %%
ruta_og = "datos/DatosDescargados/RedElectrica/GeneracionElectrica/"
years = os.listdir(ruta_og)
df_generacion = pd.DataFrame()
for year in years:
    ruta_years = os.path.join(ruta_og,year) # Entrar a cada carpeta
    archivos = os.listdir(ruta_years)
    comunidads = []
    yeardatosl = []
    for archivo in archivos:
        comunidad = archivo.split("_")[2]
        comunidads.append(comunidad)
        yeardatos = archivo.split("_")[3].strip(".json")
        yeardatosl.append(yeardatos)
        communi = []
        fechas = []
        porcentaje = []
        generacion = []
        categoria = []
        with open(f"{ruta_years}/{archivo}") as f:
            data = json.load(f)
        
        for datos in data["included"]:
            for valor in datos["attributes"]["values"]:
                communi.append(comunidad)
                categoria.append(datos["type"])
                generacion.append(valor["value"])
                porcentaje.append(valor["percentage"])
                fechas.append(valor["datetime"])
            
            df_temp = pd.DataFrame({
            "comunidad_autónoma" : communi,
            "categoria" : categoria,
            "generacion (MW)" : generacion,
            "porcentaje (%)" : porcentaje,
            "fecha" : fechas
            })
            df_generacion = pd.concat([df_generacion,df_temp])

df_generacion.head()
# Out:
#   comunidad_autónoma   categoria  generacion (MW)  porcentaje (%)  \
# 0          Andalucía  Hidráulica        25288.605        0.029517
# 1          Andalucía  Hidráulica        33933.350        0.030779
# 2          Andalucía  Hidráulica        35913.000        0.029645
# 3          Andalucía  Hidráulica        44050.848        0.041340
# 4          Andalucía  Hidráulica        88535.452        0.068497
#
#                            fecha
# 0  2019-01-01T00:00:00.000+01:00
# 1  2019-02-01T00:00:00.000+01:00
# 2  2019-03-01T00:00:00.000+01:00
# 3  2019-04-01T00:00:00.000+02:00
# 4  2019-05-01T00:00:00.000+02:00

# %% [markdown]
#   - **Datos Demográficos:** Carga los datos demográficos por provincia extraídos de la web del INE.

# %%
df_Demograficos = pd.read_csv("datos/DatosDescargados/DatosInePorProvincias2019-2021.csv",encoding='latin-1', sep = ';')
df_Demograficos.head()
# Out:
#      Provincias Edad (3 grupos de edad) Españoles/Extranjeros         Sexo  \
# 0  TOTAL ESPAÑA            TOTAL EDADES                 TOTAL  Ambos sexos
# 1  TOTAL ESPAÑA            TOTAL EDADES                 TOTAL  Ambos sexos
# 2  TOTAL ESPAÑA            TOTAL EDADES                 TOTAL  Ambos sexos
# 3  TOTAL ESPAÑA            TOTAL EDADES                 TOTAL      Hombres
# 4  TOTAL ESPAÑA            TOTAL EDADES                 TOTAL      Hombres
#
#     Año       Total
# 0  2021  47.385.107
# 1  2020  47.450.795
# 2  2019  47.026.208
# 3  2021  23.222.953
# 4  2020  23.255.590

# %% [markdown]
#   - **Datos Económicos:** Carga los datos del PIB por provincia obtenidos del INE.

# %%
df_pib = pd.read_csv("datos/DatosDescargados/DatosPIBPorProvincias2019-2021.csv",encoding='latin-1', sep = ';')
df_pib.head()
# Out:
#     Provincias Ramas de actividad                               Magnitud  \
# 0  02 Albacete     TOTAL PERSONAS       Empleo total (miles de personas)
# 1  02 Albacete     TOTAL PERSONAS       Empleo total (miles de personas)
# 2  02 Albacete     TOTAL PERSONAS       Empleo total (miles de personas)
# 3  02 Albacete     TOTAL PERSONAS       Empleo total (miles de personas)
# 4  02 Albacete     TOTAL PERSONAS  Empleo asalariado (miles de personas)
#
#    periodo  Total
# 0  2021(P)  150,2
# 1     2020  147,1
# 2     2019  151,9
# 3     2018  148,3
# 4  2021(P)  124,7

# %% [markdown]
# -Limpieza de Datos:

# %%
ruta_final = "datos/DatosFinales/RedElectrica"
os.makedirs(ruta_final,exist_ok=True)

# %% [markdown]
# - Datos de la API de REE:
#
#   - **Demanda Eléctrica:**
#
#     - **Conversión de Timestamps:** Asegúrate de que las fechas estén correctamente formateadas en `datetime`. Si es necesario, convierte los datos a un formato uniforme (por ejemplo, `YYYY-MM` para datos mensuales).
#
#     - **Tratamiento de Valores Nulos:** Identifica y maneja los valores nulos en caso de que los haya. Puedes optar por eliminar filas con valores faltantes.
#
#     - **Estandarización de Nombres de Provincias:** Verifica que los nombres de las provincias estén estandarizados y coincidan en todos los conjuntos de datos. Si hay inconsistencias, corrígelas.

# %%
df_demanda.head()
# Out:
#   comunidad_autónoma  demanda (MW)  porcentaje (%)  \
# 0          Andalucía   3668893.328               1
# 1          Andalucía   3152278.091               1
# 2          Andalucía   3216356.360               1
# 3          Andalucía   3029639.973               1
# 4          Andalucía   3154123.467               1
#
#                            fecha
# 0  2019-01-01T00:00:00.000+01:00
# 1  2019-02-01T00:00:00.000+01:00
# 2  2019-03-01T00:00:00.000+01:00
# 3  2019-04-01T00:00:00.000+02:00
# 4  2019-05-01T00:00:00.000+02:00

# %%
df_demanda["fecha"]=df_demanda["fecha"].str.split("T",expand=True)[0]
df_demanda["fecha"] = pd.to_datetime(df_demanda["fecha"])

# %%
df_demanda.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 684 entries, 0 to 11
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   comunidad_autónoma  684 non-null    object
#  1   demanda (MW)        684 non-null    float64
#  2   porcentaje (%)      684 non-null    int64
#  3   fecha               684 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 26.7+ KB

# %%
df_demanda.head()
# Out:
#   comunidad_autónoma  demanda (MW)  porcentaje (%)      fecha
# 0          Andalucía   3668893.328               1 2019-01-01
# 1          Andalucía   3152278.091               1 2019-02-01
# 2          Andalucía   3216356.360               1 2019-03-01
# 3          Andalucía   3029639.973               1 2019-04-01
# 4          Andalucía   3154123.467               1 2019-05-01

# %% [markdown]
# # Dejamos mes y año en vez de fecha

# %%
df_demanda["mes"] = df_demanda["fecha"].dt.month
df_demanda["año"] = df_demanda["fecha"].dt.year
df_demanda = df_demanda.drop(columns="fecha")

# %%
df_demanda.head()
# Out:
#   comunidad_autónoma  demanda (MW)  porcentaje (%)  mes   año
# 0          Andalucía  3668893.3280               1    1  2019
# 1          Andalucía  3152278.0910               1    2  2019
# 2          Andalucía  3216356.3600               1    3  2019
# 3          Andalucía  3029639.9730               1    4  2019
# 4          Andalucía  3154123.4670               1    5  2019

# %%
df_demanda.to_csv("datos/DatosFinales/RedElectrica/DemandaElectrica.csv")

# %% [markdown]
#  - **Generación Eléctrica:**
#
#     - **Desagregación de Tecnologías:** Asegúrate de que los datos estén correctamente desglosados por tipo de energía. Revisa que los campos correspondientes a energía eólica, solar, hidroeléctrica, etc., estén bien identificados y sin errores.
#
#     - **Normalización de Unidades:** Verifica que las unidades de energía estén estandarizadas (por ejemplo, MWh). Realiza las conversiones necesarias si se encuentran en otras unidades.
#
#     - **Identificación de Outliers:** Revisa los valores extremos o atípicos en la generación de energía y decide si deben ser tratados o eliminados.

# %%
df_generacion.head()
# Out:
#   comunidad_autónoma   categoria  generacion (MW)  porcentaje (%)       fecha
# 0          Andalucía  Hidráulica       25288.6050          0.0295  2019-01-01
# 1          Andalucía  Hidráulica       33933.3500          0.0308  2019-02-01
# 2          Andalucía  Hidráulica       35913.0000          0.0296  2019-03-01
# 3          Andalucía  Hidráulica       44050.8480          0.0413  2019-04-01
# 4          Andalucía  Hidráulica       88535.4520          0.0685  2019-05-01

# %%
df_generacion["fecha"]=df_generacion["fecha"].str.split("T",expand=True)[0]
df_generacion["fecha"] = pd.to_datetime(df_generacion["fecha"])

# %%
df_generacion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11786 entries, 0 to 71
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   comunidad_autónoma  11786 non-null  object
#  1   categoria           11786 non-null  object
#  2   generacion (MW)     11786 non-null  float64
#  3   porcentaje (%)      11786 non-null  float64
#  4   fecha               11786 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 552.5+ KB

# %%
df_generacion.head()
# Out:
#   comunidad_autónoma   categoria  generacion (MW)  porcentaje (%)      fecha
# 0          Andalucía  Hidráulica       25288.6050          0.0295 2019-01-01
# 1          Andalucía  Hidráulica       33933.3500          0.0308 2019-02-01
# 2          Andalucía  Hidráulica       35913.0000          0.0296 2019-03-01
# 3          Andalucía  Hidráulica       44050.8480          0.0413 2019-04-01
# 4          Andalucía  Hidráulica       88535.4520          0.0685 2019-05-01

# %%
df_generacion.drop_duplicates(inplace=True)
df_generacion.reset_index(drop=True,inplace=True)

# %% [markdown]
# # Separo la fecha por mes y año

# %%
df_generacion["mes"] = df_generacion["fecha"].dt.month
df_generacion["año"] = df_generacion["fecha"].dt.year
df_generacion = df_generacion.drop(columns="fecha")

# %% [markdown]
# # Quito generacion renovable
# Representa el total y lo prefiero calcular segun los datos que proveen

# %%
condicion = df_generacion["categoria"] != "Generación renovable"
df_generacion = df_generacion[condicion]

# %% [markdown]
# # Calculo el porcentaje de nuevo
#
# Ademas lo voy a hacer del 100% para tener valores mas entendibles

# %%
pd.options.display.float_format = '{:.4f}'.format
cond_2019 = df_generacion["año"] == 2019
cond_2020 = df_generacion["año"] == 2020
cond_2021 = df_generacion["año"] == 2021
df_gen2019 = df_generacion[cond_2019]
df_gen2020 = df_generacion[cond_2020]
df_gen2021 = df_generacion[cond_2021]

# %%
total_mes_comunidad2019 = df_gen2019.groupby(["mes", "comunidad_autónoma"])["generacion (MW)"].sum().to_dict()
total_mes_comunidad2020 = df_gen2020.groupby(["mes", "comunidad_autónoma"])["generacion (MW)"].sum().to_dict()
total_mes_comunidad2021 = df_gen2021.groupby(["mes", "comunidad_autónoma"])["generacion (MW)"].sum().to_dict()

df_gen2019["porcentaje (%)"] = df_gen2019.apply(
    lambda row: row["generacion (MW)"] / total_mes_comunidad2019[(row["mes"], row["comunidad_autónoma"])] * 100, axis=1
)
df_gen2020["porcentaje (%)"] = df_gen2020.apply(
    lambda row: row["generacion (MW)"] / total_mes_comunidad2020[(row["mes"], row["comunidad_autónoma"])] * 100, axis=1
)
df_gen2021["porcentaje (%)"] = df_gen2021.apply(
    lambda row: row["generacion (MW)"] / total_mes_comunidad2021[(row["mes"], row["comunidad_autónoma"])] * 100, axis=1
)

df_generacion = pd.concat([df_gen2019,df_gen2020,df_gen2021]).reset_index(drop=True)
df_generacion
# Out:
#      comunidad_autónoma         categoria  generacion (MW)  porcentaje (%)  \
# 0             Andalucía        Hidráulica       25288.6050          2.9517
# 1             Andalucía        Hidráulica       33933.3500          3.0779
# 2             Andalucía        Hidráulica       35913.0000          2.9645
# 3             Andalucía        Hidráulica       44050.8480          4.1340
# 4             Andalucía        Hidráulica       88535.4520          6.8497
# ...                 ...               ...              ...             ...
# 2904   Región de Murcia  Otras renovables        3862.0630          1.6348
# 2905   Región de Murcia  Otras renovables        3315.8530          1.5251
# 2906   Región de Murcia  Otras renovables        3266.0950          1.7445
# 2907   Región de Murcia  Otras renovables        2672.0510          1.3830
# 2908   Región de Murcia  Otras renovables        2955.5620          1.7457
#
#       mes   año
# 0       1  2019
# 1       2  2019
# 2       3  2019
# 3       4  2019
# 4       5  2019
# ...   ...   ...
# 2904    8  2021
# 2905    9  2021
# 2906   10  2021
# 2907   11  2021
# 2908   12  2021
#
# [2909 rows x 6 columns]

# %%
df_generacion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2909 entries, 0 to 2908
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   comunidad_autónoma  2909 non-null   object
#  1   categoria           2909 non-null   object
#  2   generacion (MW)     2909 non-null   float64
#  3   porcentaje (%)      2909 non-null   float64
#  4   mes                 2909 non-null   int32
#  5   año                 2909 non-null   int32
# dtypes: float64(2), int32(2), object(2)
# memory usage: 113.8+ KB

# %%
df_generacion.to_csv("datos/DatosFinales/RedElectrica/GeneracionElectrica.csv")

# %% [markdown]
# - Datos del INE:
#
#   - **Datos Demográficos:**
#
#     - **Consistencia en la Codificación de Provincias:** Asegúrate de que los nombres de las provincias en los datos demográficos coincidan con los nombres utilizados en los datos eléctricos.
#
#     - **Revisión de Categorías:** Verifica que las categorías de edad, sexo, y nacionalidad estén correctamente etiquetadas y sean consistentes en todo el dataset.
#
#     - **Manejo de Valores Faltantes:** Revisa la presencia de valores faltantes y decide cómo tratarlos (relleno, eliminación o sustitución).

# %%
df_demograficos = pd.read_csv("datos/DatosDescargados/DatosInePorProvincias2019-2021.csv",encoding='latin-1', sep = ';')
df_Demograficos.head()
# Out:
#      Provincias Edad (3 grupos de edad) Españoles/Extranjeros         Sexo  \
# 0  TOTAL ESPAÑA            TOTAL EDADES                 TOTAL  Ambos sexos
# 1  TOTAL ESPAÑA            TOTAL EDADES                 TOTAL  Ambos sexos
# 2  TOTAL ESPAÑA            TOTAL EDADES                 TOTAL  Ambos sexos
# 3  TOTAL ESPAÑA            TOTAL EDADES                 TOTAL      Hombres
# 4  TOTAL ESPAÑA            TOTAL EDADES                 TOTAL      Hombres
#
#     Año       Total
# 0  2021  47.385.107
# 1  2020  47.450.795
# 2  2019  47.026.208
# 3  2021  23.222.953
# 4  2020  23.255.590

# %%
cond1 = df_Demograficos["Provincias"] != "TOTAL ESPAÑA"
cond2 = df_Demograficos["Edad (3 grupos de edad)"] != "TOTAL EDADES"
cond3 = df_Demograficos["Españoles/Extranjeros"] != "TOTAL"
cond4 = df_Demograficos["Sexo"] != "Ambos sexos"
cond5 = df_Demograficos["Españoles/Extranjeros"] != f"% Extranjeros"
df_Demograficos = df_Demograficos[cond1 & cond2 & cond3 & cond4 & cond5].reset_index(drop=True)
df_Demograficos
# Out:
#        Provincias Edad (3 grupos de edad) Españoles/Extranjeros     Sexo  \
# 0     02 Albacete               0-15 años             Españoles  Hombres
# 1     02 Albacete               0-15 años             Españoles  Hombres
# 2     02 Albacete               0-15 años             Españoles  Hombres
# 3     02 Albacete               0-15 años             Españoles  Mujeres
# 4     02 Albacete               0-15 años             Españoles  Mujeres
# ...           ...                     ...                   ...      ...
# 1867   52 Melilla                65 y más           Extranjeros  Hombres
# 1868   52 Melilla                65 y más           Extranjeros  Hombres
# 1869   52 Melilla                65 y más           Extranjeros  Mujeres
# 1870   52 Melilla                65 y más           Extranjeros  Mujeres
# 1871   52 Melilla                65 y más           Extranjeros  Mujeres
#
#        Año   Total
# 0     2021  27.304
# 1     2020  27.979
# 2     2019  28.513
# 3     2021  25.547
# 4     2020  25.953
# ...    ...     ...
# 1867  2020     447
# 1868  2019     422
# 1869  2021     489
# 1870  2020     486
# 1871  2019     443
#
# [1872 rows x 6 columns]

# %%
df_Demograficos["Provincias"] = df_Demograficos["Provincias"].str.replace(r'^\d{2} ', '', regex=True)

# %%
provincias = df_Demograficos["Provincias"].unique().tolist()

# %% [markdown]
# # Diccionario de Comunidad autónomas por provincia

# %%
provincias_a_comunidad = {
    "Albacete": "Castilla-La Mancha",
    "Alicante/Alacant": "Comunidad Valenciana",
    "Almería": "Andalucía",
    "Araba/Álava": "País Vasco",
    "Asturias": "Asturias",
    "Ávila": "Castilla y León",
    "Badajoz": "Extremadura",
    "Balears, Illes": "Islas Baleares",
    "Barcelona": "Cataluña",
    "Bizkaia": "País Vasco",
    "Burgos": "Castilla y León",
    "Cáceres": "Extremadura",
    "Cádiz": "Andalucía",
    "Cantabria": "Cantabria",
    "Castellón/Castelló": "Comunidad Valenciana",
    "Ciudad Real": "Castilla-La Mancha",
    "Córdoba": "Andalucía",
    "Coruña, A": "Galicia",
    "Cuenca": "Castilla-La Mancha",
    "Gipuzkoa": "País Vasco",
    "Girona": "Cataluña",
    "Granada": "Andalucía",
    "Guadalajara": "Castilla-La Mancha",
    "Huelva": "Andalucía",
    "Huesca": "Aragón",
    "Jaén": "Andalucía",
    "León": "Castilla y León",
    "Lleida": "Cataluña",
    "Lugo": "Galicia",
    "Madrid": "Comunidad de Madrid",
    "Málaga": "Andalucía",
    "Murcia": "Región de Murcia",
    "Navarra": "Navarra",
    "Ourense": "Galicia",
    "Palencia": "Castilla y León",
    "Palmas, Las": "Canarias",
    "Pontevedra": "Galicia",
    "Rioja, La": "La Rioja",
    "Salamanca": "Castilla y León",
    "Santa Cruz de Tenerife": "Canarias",
    "Segovia": "Castilla y León",
    "Sevilla": "Andalucía",
    "Soria": "Castilla y León",
    "Tarragona": "Cataluña",
    "Teruel": "Aragón",
    "Toledo": "Castilla-La Mancha",
    "Valencia/València": "Comunidad Valenciana",
    "Valladolid": "Castilla y León",
    "Zamora": "Castilla y León",
    "Zaragoza": "Aragón",
    "Ceuta": "Ceuta",
    "Melilla": "Melilla"
}

# %%
df_Demograficos['comunidad_autonoma'] = df_Demograficos["Provincias"].map(provincias_a_comunidad)

df_Demograficos.columns = [col.lower() for col in df_Demograficos.columns]

df_Demograficos = df_Demograficos[[df_Demograficos.columns[-1]] + list(df_Demograficos.columns[:-1])]

# %%
df_Demograficos["total"] = df_Demograficos["total"].str.replace(".","")

# %%
df_Demograficos.head()
# Out:
#    comunidad_autonoma provincias edad (3 grupos de edad)  \
# 0  Castilla-La Mancha   Albacete               0-15 años
# 1  Castilla-La Mancha   Albacete               0-15 años
# 2  Castilla-La Mancha   Albacete               0-15 años
# 3  Castilla-La Mancha   Albacete               0-15 años
# 4  Castilla-La Mancha   Albacete               0-15 años
#
#   españoles/extranjeros     sexo   año  total
# 0             Españoles  Hombres  2021  27304
# 1             Españoles  Hombres  2020  27979
# 2             Españoles  Hombres  2019  28513
# 3             Españoles  Mujeres  2021  25547
# 4             Españoles  Mujeres  2020  25953

# %%
df_Demograficos.to_csv("datos/DatosFinales/INE/DatosDemograficos2019-2021.csv")

# %% [markdown]
#   - **Datos Económicos:**
#
#     - **Normalización del PIB:** Si los datos del PIB están en diferentes unidades o escalas, asegúrate de normalizarlos para que sean comparables entre provincias.
#
#     - **Agrupación Temporal:** Si los datos económicos están disponibles en diferentes periodos temporales, agrúpalos y normalízalos para que coincidan con los datos eléctricos en términos de granularidad temporal (mensual o anual).
#
# NOTA: Ten en cuenta que los datos los vamos a tener que insertar en una base de datos mañana, por lo que toda esta limpieza os recomendamos que la penséis para poder crear e insertar los datos mañana.

# %%
df_economicos = pd.read_csv("datos/DatosDescargados/DatosPIBPorProvincias2019-2021.csv",encoding='latin-1', sep = ';')
df_economicos.head()
# Out:
#     Provincias Ramas de actividad                               Magnitud  \
# 0  02 Albacete     TOTAL PERSONAS       Empleo total (miles de personas)
# 1  02 Albacete     TOTAL PERSONAS       Empleo total (miles de personas)
# 2  02 Albacete     TOTAL PERSONAS       Empleo total (miles de personas)
# 3  02 Albacete     TOTAL PERSONAS       Empleo total (miles de personas)
# 4  02 Albacete     TOTAL PERSONAS  Empleo asalariado (miles de personas)
#
#    periodo  Total
# 0  2021(P)  150,2
# 1     2020  147,1
# 2     2019  151,9
# 3     2018  148,3
# 4  2021(P)  124,7

# %%
cond1 = df_economicos["Ramas de actividad"] != "TOTAL PERSONAS"
cond2 = df_economicos["periodo"] != "2018"
df_economicos = df_economicos[cond1 & cond2].reset_index(drop=True)

# %%
df_economicos
# Out:
#        Provincias                                 Ramas de actividad  \
# 0     02 Albacete    A. Agricultura, ganadería, silvicultura y pesca
# 1     02 Albacete    A. Agricultura, ganadería, silvicultura y pesca
# 2     02 Albacete    A. Agricultura, ganadería, silvicultura y pesca
# 3     02 Albacete    A. Agricultura, ganadería, silvicultura y pesca
# 4     02 Albacete    A. Agricultura, ganadería, silvicultura y pesca
# ...           ...                                                ...
# 2179   52 Melilla  O_U. Administración pública y defensa, segurid...
# 2180   52 Melilla  O_U. Administración pública y defensa, segurid...
# 2181   52 Melilla  O_U. Administración pública y defensa, segurid...
# 2182   52 Melilla  O_U. Administración pública y defensa, segurid...
# 2183   52 Melilla  O_U. Administración pública y defensa, segurid...
#
#                                    Magnitud  periodo Total
# 0          Empleo total (miles de personas)  2021(P)  15,3
# 1          Empleo total (miles de personas)     2020  15,3
# 2          Empleo total (miles de personas)     2019  14,3
# 3     Empleo asalariado (miles de personas)  2021(P)  11,5
# 4     Empleo asalariado (miles de personas)     2020  10,9
# ...                                     ...      ...   ...
# 2179       Empleo total (miles de personas)     2020  18,0
# 2180       Empleo total (miles de personas)     2019  17,7
# 2181  Empleo asalariado (miles de personas)  2021(P)  18,3
# 2182  Empleo asalariado (miles de personas)     2020  17,5
# 2183  Empleo asalariado (miles de personas)     2019  17,3
#
# [2184 rows x 5 columns]

# %%
df_economicos["Provincias"] = df_economicos["Provincias"].str.replace(r'^\d{2} ', '', regex=True)
provincias = df_economicos["Provincias"].unique().tolist()

# %%
provincias_a_comunidad = {
    "Albacete": "Castilla-La Mancha",
    "Alicante/Alacant": "Comunidad Valenciana",
    "Almería": "Andalucía",
    "Araba/Álava": "País Vasco",
    "Asturias": "Asturias",
    "Ávila": "Castilla y León",
    "Badajoz": "Extremadura",
    "Balears, Illes": "Islas Baleares",
    "Barcelona": "Cataluña",
    "Bizkaia": "País Vasco",
    "Burgos": "Castilla y León",
    "Cáceres": "Extremadura",
    "Cádiz": "Andalucía",
    "Cantabria": "Cantabria",
    "Castellón/Castelló": "Comunidad Valenciana",
    "Ciudad Real": "Castilla-La Mancha",
    "Córdoba": "Andalucía",
    "Coruña, A": "Galicia",
    "Cuenca": "Castilla-La Mancha",
    "Gipuzkoa": "País Vasco",
    "Girona": "Cataluña",
    "Granada": "Andalucía",
    "Guadalajara": "Castilla-La Mancha",
    "Huelva": "Andalucía",
    "Huesca": "Aragón",
    "Jaén": "Andalucía",
    "León": "Castilla y León",
    "Lleida": "Cataluña",
    "Lugo": "Galicia",
    "Madrid": "Comunidad de Madrid",
    "Málaga": "Andalucía",
    "Murcia": "Región de Murcia",
    "Navarra": "Navarra",
    "Ourense": "Galicia",
    "Palencia": "Castilla y León",
    "Palmas, Las": "Canarias",
    "Pontevedra": "Galicia",
    "Rioja, La": "La Rioja",
    "Salamanca": "Castilla y León",
    "Santa Cruz de Tenerife": "Canarias",
    "Segovia": "Castilla y León",
    "Sevilla": "Andalucía",
    "Soria": "Castilla y León",
    "Tarragona": "Cataluña",
    "Teruel": "Aragón",
    "Toledo": "Castilla-La Mancha",
    "Valencia/València": "Comunidad Valenciana",
    "Valladolid": "Castilla y León",
    "Zamora": "Castilla y León",
    "Zaragoza": "Aragón",
    "Ceuta": "Ceuta",
    "Melilla": "Melilla"
}

# %%
df_economicos['comunidad_autonoma'] = df_economicos["Provincias"].map(provincias_a_comunidad)

df_economicos.columns = [col.lower() for col in df_economicos.columns]

df_economicos = df_economicos[[df_economicos.columns[-1]] + list(df_economicos.columns[:-1])]

# %%
df_economicos["periodo"]=df_economicos["periodo"].str.strip("(P)").astype(int)

# %%
df_economicos.head()
# Out:
#    comunidad_autonoma provincias  \
# 0  Castilla-La Mancha   Albacete
# 1  Castilla-La Mancha   Albacete
# 2  Castilla-La Mancha   Albacete
# 3  Castilla-La Mancha   Albacete
# 4  Castilla-La Mancha   Albacete
#
#                                 ramas de actividad  \
# 0  A. Agricultura, ganadería, silvicultura y pesca
# 1  A. Agricultura, ganadería, silvicultura y pesca
# 2  A. Agricultura, ganadería, silvicultura y pesca
# 3  A. Agricultura, ganadería, silvicultura y pesca
# 4  A. Agricultura, ganadería, silvicultura y pesca
#
#                                 magnitud  periodo total
# 0       Empleo total (miles de personas)     2021  15,3
# 1       Empleo total (miles de personas)     2020  15,3
# 2       Empleo total (miles de personas)     2019  14,3
# 3  Empleo asalariado (miles de personas)     2021  11,5
# 4  Empleo asalariado (miles de personas)     2020  10,9

# %%
df_economicos["total"] = df_economicos["total"].str.replace(".","").str.replace(",",".").astype(float)

# %%
df_economicos
# Out:
#       comunidad_autonoma provincias  \
# 0     Castilla-La Mancha   Albacete
# 1     Castilla-La Mancha   Albacete
# 2     Castilla-La Mancha   Albacete
# 3     Castilla-La Mancha   Albacete
# 4     Castilla-La Mancha   Albacete
# ...                  ...        ...
# 2179             Melilla    Melilla
# 2180             Melilla    Melilla
# 2181             Melilla    Melilla
# 2182             Melilla    Melilla
# 2183             Melilla    Melilla
#
#                                      ramas de actividad  \
# 0       A. Agricultura, ganadería, silvicultura y pesca
# 1       A. Agricultura, ganadería, silvicultura y pesca
# 2       A. Agricultura, ganadería, silvicultura y pesca
# 3       A. Agricultura, ganadería, silvicultura y pesca
# 4       A. Agricultura, ganadería, silvicultura y pesca
# ...                                                 ...
# 2179  O_U. Administración pública y defensa, segurid...
# 2180  O_U. Administración pública y defensa, segurid...
# 2181  O_U. Administración pública y defensa, segurid...
# 2182  O_U. Administración pública y defensa, segurid...
# 2183  O_U. Administración pública y defensa, segurid...
#
#                                    magnitud  periodo   total
# 0          Empleo total (miles de personas)     2021 15.3000
# 1          Empleo total (miles de personas)     2020 15.3000
# 2          Empleo total (miles de personas)     2019 14.3000
# 3     Empleo asalariado (miles de personas)     2021 11.5000
# 4     Empleo asalariado (miles de personas)     2020 10.9000
# ...                                     ...      ...     ...
# 2179       Empleo total (miles de personas)     2020 18.0000
# 2180       Empleo total (miles de personas)     2019 17.7000
# 2181  Empleo asalariado (miles de personas)     2021 18.3000
# 2182  Empleo asalariado (miles de personas)     2020 17.5000
# 2183  Empleo asalariado (miles de personas)     2019 17.3000
#
# [2184 rows x 6 columns]

# %%
df_economicos.to_csv("datos/DatosFinales/INE/DatosPIB2019-2021.csv")

# %% [markdown]
# Si has llegado hasta aquí, pido perdon por la basura de código, se que no está bien y que básicamente es una basura.
#
# De hecho creo que se aprecia la decadencia según vas bajando.
#
# No fue mi mejor día, se me peto la cabeza empecé a hacer tonterías.
